# %% [markdown]
# ## Regression model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\PC\Desktop\regression\regression.csv")

# %%
# create x and y
x = data["X"]
y = data["Y"]

# distributin of data 

plt.scatter(x,y)

# %%
data
# Out:
#             X           Y
# 0   32.669044   45.570589
# 1   40.166899   54.084055
# 2   53.575078   87.994453
# 3   33.864215   52.725494
# 4   64.707139   93.576119
# 5   38.119824   80.166275
# 6   44.502538   65.101712
# 7   40.599538   65.562301
# 8   41.720676   65.280887
# 9   51.088635   73.434642
# 10  55.078096   71.139728
# 11  41.377727   79.102830
# 12  62.494697   86.520538
# 13  49.203888   84.742698
# 14  41.102685   59.358850
# 15  41.182016   61.684038
# 16  50.186389   69.847604
# 17  52.378446   86.098291
# 18  50.135485   59.108839
# 19  33.644706   69.899682
# 20  39.557901   44.862491
# 21  56.130389   85.498068
# 22  57.362052   95.536687
# 23  60.269214   70.251934
# 24  35.678094   52.721735
# 25  31.588117   50.392670
# 26  53.660932   63.642399
# 27  46.682229   72.247251
# 28  43.107820   57.812513
# 29  70.346076  104.257102
# 30  44.492856   86.642020
# 31  57.504533   91.486778
# 32  36.930077   55.231661
# 33  55.805733   79.550437
# ...

# %%
# train test split from skit learn
from sklearn.model_selection import train_test_split

# build train and test sets

X_train , X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# distribution of training data and testing data
 
def train_test_distribution(X_train , X_test, y_train, y_test):
    plt.scatter(X_train, y_train)
    plt.scatter(X_test, y_test)
    
train_test_distribution(X_train , X_test, y_train, y_test)

# %%
# use skilit learn regression model
import numpy as np
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

reg = make_pipeline(StandardScaler(),
                     SGDRegressor(max_iter=1000, tol=1e-3))

reg.fit(X
# Out:
# C:\Users\PC\anaconda3\envs\tensor-gpu-test\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# create a linear regression object
regr = linear_model.LinearRegression()

X = X_train.values.reshape(-1,1)
Y = y_train.values.ravel()


# Train the model using the training sets
regr.fit(X,Y)

# Make predictions using the testing set
y_pred = regr.predict(X_test)
y_pred
# Out:
# array([85.1419845 , 59.46889216, 57.8931917 , 74.14861637, 53.54204969,
#        99.4651328 , 76.64488673, 80.05152258, 67.53702277, 91.7509536 ,
#        75.25540137])

# %%
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 121.97

# %%
# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

# %% [markdown]
# ## Model is generalized well
