# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-de3efb970f08> in <module>
#       1 import numpy as np
#       2
# ----> 3 x = tf.constant(np.arrange(1,100))
#
# ~\anaconda3\envs\tensor-gpu-test\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     302
#     303             raise AttributeError("module {!r} has no attribute "
# --> 304                                  "{!r}".format(__name__, attr))
#     305
#     306         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'arrange'
